# %% [markdown]
# # Nguyên

# %% [markdown]
# # Dự án: Echo Valley - Dự án Phân tích Thương mại điện tử Olist
# **Tên Notebook:** 05_modeling_prediction.ipynb
# **Mục tiêu:** Xây dựng mô hình Machine Learning dự báo thời gian giao hàng và sử dụng thuật toán phân cụm (Clustering) để gợi ý vị trí kho bãi tối ưu.

# %% [markdown]
# # 1. Chuẩn bị dữ liệu cho Model

# %% [markdown]
# ## 1.1 Feature Engineering

# %%
# Code mã hóa biến phân loại (One-hot encoding/Label encoding)
# Code xử lý biến thời gian (tách day, month, hour, weekday)
# Code chọn lọc các features quan trọng: price, freight_value, distance, etc.

# %% [markdown]
# # 2. Xây dựng mô hình dự báo thời gian giao hàng

# %% [markdown]
# ## 2.1 Huấn luyện mô hình (Regression)

# %%
# Code train-test split
# Code huấn luyện mô hình (Linear Regression / Random Forest / XGBoost)
# Code đánh giá mô hình (MAE, RMSE, R-squared)

# %% [markdown]
# **Nhận xét:**
# - [Điền nhận xét: Mô hình có độ chính xác thế nào? Yếu tố nào ảnh hưởng nhất tới thời gian giao hàng (Feature Importance)?]

# %% [markdown]
# # 3. Gợi ý vị trí kho bãi tối ưu (Strategy)

# %% [markdown]
# ## 3.1 Phân cụm khách hàng (Clustering)

# %% [markdown]
# **a.** Sử dụng K-Means Clustering trên tọa độ địa lý (latitude, longitude) của khách hàng để tìm trung tâm các cụm.

# %%
# Code K-Means clustering
# Code plot các cụm khách hàng và tâm điểm (centoids) dự kiến đặt kho

# %% [markdown]
# **Nhận xét:**
# - [Điền nhận xét: Dựa vào các cụm, vị trí kho bãi nào là tối ưu nhất để giảm thời gian giao hàng tổng thể?]

# %% [markdown]
# # 4. Kết luận và Đề xuất

# %% [markdown]
# ## 4.1 Tóm tắt đề xuất cho Olist

# %% [markdown]
# - **Về dự báo:** Độ chính xác của mô hình là bao nhiêu?
# - **Về kho bãi:** Đề xuất đặt kho ở bang/thành phố nào?
# - **Hành động tiếp theo:** Nhóm đề xuất gì để cải thiện chuỗi cung ứng?
