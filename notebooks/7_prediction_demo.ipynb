# %% [markdown]
# # Đạt

# %% [markdown]
# # Dự án: Echo Valley - Dự án Phân tích Thương mại điện tử Olist
# **Tên Notebook:** 07_streamlit_dashboard.ipynb
# **Mục tiêu:** Xây dựng prototype cho Dashboard bằng Streamlit để trực quan hóa các insight về chuỗi cung ứng và tích hợp mô hình dự báo đã huấn luyện.

# %% [markdown]
# # 1. Setup môi trường Streamlit

# %% [markdown]
# ## 1.1 Import thư viện hiển thị

# %%
# Import streamlit, plotly (để vẽ chart tương tác), và các hàm load_model/data đã chuẩn bị

# %% [markdown]
# **Nhận xét:**
# - [Điền nhận xét: Đã load thành công dữ liệu sạch và mô hình đã train]

# %% [markdown]
# # 2. Xây dựng Layout Dashboard

# %% [markdown]
# ## 2.1 Thiết kế Sidebar và Title

# %% [markdown]
# ### 2.1.1 Định nghĩa các bộ lọc

# %% [markdown]
# **a.** Tạo các dropdown để người dùng chọn khu vực (State/City) hoặc loại sản phẩm

# %%
# Code tạo các sidebar filters (st.sidebar.selectbox)

# %% [markdown]
# **Nhận xét:**
# - [Điền nhận xét: Người dùng có thể lọc dữ liệu để xem các phân đoạn khác nhau không?]

# %% [markdown]
# # 3. Trực quan hóa dữ liệu (Visualization)

# %% [markdown]
# ## 3.1 Hiển thị các chỉ số chính (KPIs)

# %% [markdown]
# ### 3.1.1 Các biểu đồ Bottleneck và Map

# %% [markdown]
# **a.** Vẽ biểu đồ (Plotly/Altair) hiển thị thời gian giao hàng và map phân bổ kho

# %%
# Code hiển thị biểu đồ so sánh hoặc bản đồ (st.plotly_chart hoặc st.map)

# %% [markdown]
# **Nhận xét:**
# - [Điền nhận xét: Biểu đồ có phản ánh đúng các điểm nghẽn chuỗi cung ứng không?]

# %% [markdown]
# # 4. Tích hợp Dự báo (Prediction Interface)

# %% [markdown]
# ## 4.1 Input để dự báo thời gian giao hàng

# %% [markdown]
# **a.** Tạo form nhập liệu (Distance, Product Type) và nút "Dự báo"

# %%
# Code tạo st.number_input/st.text_input và nút st.button để gọi mô hình

# %% [markdown]
# **Nhận xét:**
# - [Điền nhận xét: Dashboard có hiển thị kết quả dự báo chính xác khi nhập liệu không?]

# %% [markdown]
# # 5. Chuẩn bị đưa vào production

# %% [markdown]
# ## 5.1 Ghi chú logic cho file app

# %%
# Note lại các đoạn code cần copy sang app/streamlit_app.py
