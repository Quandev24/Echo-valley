# %% [markdown]
# # Thắng

# %% [markdown]
# # Dự án: Echo Valley - Dự án Phân tích Thương mại điện tử Olist
# **Tên Notebook:** 01_data_understanding.ipynb
# **Mục tiêu:** Khám phá cấu trúc, quy mô và chất lượng ban đầu của 9 bảng dữ liệu trong bộ dataset Olist.

# %% [markdown]
# # 1. Nhập thư viện và nạp dữ liệu

# %%
# Nhập thư viện cần thiết
import pandas as pd
import os

# Nạp 9 file CSV vào biến DataFrame (Ví dụ: df_orders, df_customers...)
# Gợi ý: Dùng vòng lặp hoặc đọc thủ công từng file từ thư mục data/archive/

# %% [markdown]
# **Nhận xét:**
# - [Điền nhận xét của bạn sau khi chạy code nạp dữ liệu]

# %% [markdown]
# # 2. Tổng quan cấu trúc dữ liệu

# %% [markdown]
# ## 2.1 Kiểm tra thông tin các bảng

# %% [markdown]
# ### 2.1.1 Xem hình dáng (Shape) của từng bảng

# %% [markdown]
# **a.** In ra kích thước (rows, columns) của 9 bảng

# %%
# Code kiểm tra shape của các dataframe
# Ví dụ: print(df_orders.shape)

# %% [markdown]
# **Nhận xét:**
# - [Điền nhận xét về quy mô các bảng]

# %% [markdown]
# ### 2.1.2 Kiểm tra kiểu dữ liệu (Data types) và giá trị null

# %% [markdown]
# **a.** Sử dụng hàm .info() cho các bảng

# %%
# Code sử dụng .info() cho các bảng

# %% [markdown]
# **Nhận xét:**
# - [Điền nhận xét về kiểu dữ liệu và các cột cần xử lý null]

# %% [markdown]
# # 3. Kiểm tra dữ liệu trùng lặp

# %% [markdown]
# ## 3.1 Kiểm tra trùng lặp trên các bảng chính

# %% [markdown]
# ### 3.1.1 Kiểm tra số lượng dòng trùng

# %% [markdown]
# **a.** Sử dụng hàm .duplicated().sum()

# %%
# Code kiểm tra trùng lặp

# %% [markdown]
# **Nhận xét:**
# - [Điền nhận xét về dữ liệu trùng lặp]

# %% [markdown]
# # 4. Tổng quan thống kê (Statistical Summary)

# %% [markdown]
# ## 4.1 Thống kê mô tả

# %% [markdown]
# ### 4.1.1 Xem phân phối của dữ liệu số

# %% [markdown]
# **a.** Sử dụng hàm .describe() cho các cột số

# %%
# Code mô tả thống kê

# %% [markdown]
# **Nhận xét:**
# - [Điền nhận xét về các giá trị bất thường (outliers)]

# %% [markdown]
# # 5. Phân tích sơ bộ mối quan hệ (Data Dictionary check)

# %% [markdown]
# ## 5.1 Kiểm tra khóa chính và khóa ngoại

# %% [markdown]
# ### 5.1.1 Kiểm tra các cột định danh

# %% [markdown]
# **a.** Kiểm tra tính duy nhất của ID (Primary Key)

# %%
# Code kiểm tra tính duy nhất (is_unique)

# %% [markdown]
# **Nhận xét:**
# - [Điền nhận xét về khóa chính của các bảng]
