# %% [markdown]
# # Tới

# %% [markdown]
# # Dự án: Echo Valley - Dự án Phân tích Thương mại điện tử Olist
# **Tên Notebook:** 04_eda_visualization.ipynb
# **Mục tiêu:** Thực hiện EDA (Exploratory Data Analysis) và trực quan hóa dữ liệu để tìm ra các điểm nghẽn (bottlenecks) trong chuỗi cung ứng và hành vi khách hàng.

# %% [markdown]
# # 1. Nạp dữ liệu sạch

# %% [markdown]
# ## 1.1 Load dữ liệu đã làm sạch

# %%
# Code import thư viện (pandas, matplotlib, seaborn, v.v.)
# Code load file từ data/processed/

# %% [markdown]
# **Nhận xét:**
# - [Điền nhận xét về việc nạp dữ liệu thành công]

# %% [markdown]
# # 2. Phân tích địa lý và Khoảng cách

# %% [markdown]
# ## 2.1 Tính toán khoảng cách (Distance Engineering)

# %% [markdown]
# ### 2.1.1 Tính khoảng cách Haversine giữa khách hàng và người bán

# %%
# Code tính khoảng cách địa lý (Haversine distance)

# %% [markdown]
# **Nhận xét:**
# - [Điền nhận xét: Có mối tương quan nào giữa khoảng cách và thời gian giao hàng không?]

# %% [markdown]
# # 3. Phân tích điểm nghẽn (Bottleneck Analysis)

# %% [markdown]
# ## 3.1 Thời gian giao hàng thực tế vs. Dự kiến

# %% [markdown]
# ### 3.1.1 So sánh thời gian giao hàng

# %%
# Code tính hiệu số: thời gian giao thực tế vs thời gian ước tính
# Code vẽ biểu đồ phân phối thời gian giao hàng

# %% [markdown]
# **Nhận xét:**
# - [Điền nhận xét: Tìm thấy vùng/bang nào có thời gian giao hàng chậm nhất?]

# %% [markdown]
# # 4. Trực quan hóa xu hướng & Hành vi

# %% [markdown]
# ## 4.1 Phân tích các yếu tố ảnh hưởng

# %% [markdown]
# ### 4.1.1 Biểu đồ nhiệt (Heatmap) hoặc Bar chart

# %%
# Code vẽ biểu đồ (Ví dụ: Số đơn hàng theo bang, top sản phẩm chậm trễ...)

# %% [markdown]
# **Nhận xét:**
# - [Điền các Insight quan trọng nhất rút ra được từ biểu đồ]
